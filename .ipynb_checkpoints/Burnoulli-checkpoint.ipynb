# %%
from scipy.stats import binom
from matplotlib import pyplot as plt
import numpy as np
import math

n=10000
p=0.4
alpha=0.05
res=[]
output=[]
for j in range(1,n+1):
    epsilon=math.sqrt(math.log(2/alpha)/(2*j))
    interval=2*epsilon
    res.append(interval)
    if interval<=alpha:
        output.append(j)
print(output[0])
plt.plot(np.arange(1,n+1),res,color='b')
plt.plot(np.arange(1,n+1),np.ones((n,1))*(alpha),color='r')
plt.grid(True,linewidth=0.5)
plt.xlabel('$N$')
plt.ylabel('Length of Interval')
plt.title('Length of Interval versus N')
# Out:
# 2952
# Text(0.5, 1.0, 'Length of Interval versus N')

# %%
from scipy.stats import binom
from matplotlib import pyplot as plt
import numpy as np
import math

n=10000
p=0.4
alpha=0.05
size=1000
# k=np.arange(0,size)
res=[]
for j in range(1,n+1):
    count=0
    p_n=np.random.binomial(j,p,size)/j
#     p_n = binom.cdf(k, j, p)/j
    epsilon=math.sqrt(math.log(2/alpha)/(2*j))
    left_bound=p_n-epsilon
    right_bound=p_n+epsilon
    for i in range(size):
        if left_bound[i]<p<right_bound[i]:
            count+=1
    res.append(count/size)
plt.plot(np.arange(1,n+1),res,markersize=0.5,color='b')
plt.plot(np.arange(1,n+1),np.ones((n,1))*(1-alpha),markersize=0.5,color='r')
plt.grid(True,linewidth=0.5)
plt.xlabel('$N$')
plt.ylabel('$Converge$')
plt.title('Converge Versus N')
# Out:
# Text(0.5, 1.0, 'Converge Versus N')

# %%
import numpy as np
a=np.random.binomial(100,0.4,1000)
print(a)
# Out:
# [36 33 45 48 51 45 38 36 41 35 43 44 28 46 41 45 51 47 42 47 40 33 47 43
#  40 41 38 37 34 39 39 36 35 47 40 45 36 47 38 40 48 34 43 39 37 38 46 44
#  37 47 38 36 32 36 33 39 45 44 48 43 37 54 39 43 40 38 42 38 40 40 41 42
#  46 44 47 38 34 31 50 41 45 42 34 44 41 43 39 39 33 52 47 36 43 33 36 39
#  44 39 36 46 48 46 41 43 48 44 42 49 30 35 38 40 42 40 36 38 53 41 45 33
#  47 40 46 45 35 46 41 35 42 37 30 32 43 37 48 37 41 42 40 41 40 44 36 37
#  44 37 41 50 49 41 43 37 39 35 30 45 33 36 41 40 38 47 34 35 44 34 41 44
#  46 32 39 38 37 45 37 42 39 44 37 45 26 41 40 34 49 44 39 41 44 45 24 38
#  42 42 46 42 41 44 36 39 48 40 36 33 43 36 37 48 24 41 49 43 40 38 39 38
#  43 38 41 41 27 38 43 33 49 37 37 38 43 47 33 46 36 42 40 41 54 44 34 49
#  50 43 39 36 43 43 43 31 36 37 38 35 35 38 37 45 45 38 33 40 47 50 43 39
#  46 40 37 41 41 47 43 38 43 35 33 40 37 44 38 33 42 44 42 43 39 48 40 44
#  42 49 34 40 40 44 44 39 43 42 43 34 44 45 36 49 46 30 45 41 45 45 34 37
